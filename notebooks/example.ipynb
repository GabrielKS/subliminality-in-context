# %% [markdown]
# # Example notebook
#
# Demonstrates that notebooks depend on the `subliminality` library.

# %%
from subliminality import greet

greet("notebook")
# Out:
# 'Hello, notebook, from subliminality!'
